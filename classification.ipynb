# %% [markdown]
# ## *Aprendizado Supervisionado - Classificação*

# %% [markdown]
# ## 1.0 Import Libraries

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics as mt

# %% [markdown]
# ### 1.1 Load Dataset

# %%
dataset_path = r'C:\\Users\\flp61\\Documents\\fundamentos_ml\\train.csv'
df = pd.read_csv( dataset_path )

# %%
df.head()
# Out:
#    id_cliente  idade  saldo_atual  divida_atual  renda_anual  \
# 0        1767     21   278.172008       2577.05  24196.89636
# 1       11920     40   268.874152       2465.39  19227.37796
# 2        8910     36   446.643127       1055.29  42822.28223
# 3        4964     58   321.141267        703.05  51786.82600
# 4       10100     35   428.716114        891.29  44626.85346
#
#    valor_em_investimentos  taxa_utilizacao_credito  num_emprestimos  \
# 0              104.306544                31.038763                6
# 1               69.858778                36.917093                5
# 2              134.201478                34.561714                0
# 3              297.350067                31.493561                0
# 4              134.201478                28.028887                2
#
#    num_contas_bancarias  num_cartoes_credito  dias_atraso_dt_venc  \
# 0                     5                    7                   21
# 1                     8                    5                   40
# 2                     3                    6                   26
# 3                     3                    7                   12
# 4                     8                    7                   24
#
#    num_pgtos_atrasados  num_consultas_credito  taxa_juros investe_exterior  \
# 0                   14                      9          15              Não
# 1                   23                     10          18              Não
# 2                   13                      3          15              Sim
# 3                    7                      2           1              Sim
# 4                   10                      8          20              Sim
#
#   pessoa_polit_exp limite_adicional
# 0              Não            Negar
# 1              Não            Negar
# 2              Não            Negar
# 3              Não            Negar
# 4              Não            Negar

# %%
df.columns
# Out:
# Index(['id_cliente', 'idade', 'saldo_atual', 'divida_atual', 'renda_anual',
#        'valor_em_investimentos', 'taxa_utilizacao_credito', 'num_emprestimos',
#        'num_contas_bancarias', 'num_cartoes_credito', 'dias_atraso_dt_venc',
#        'num_pgtos_atrasados', 'num_consultas_credito', 'taxa_juros',
#        'investe_exterior', 'pessoa_polit_exp', 'limite_adicional'],
#       dtype='object')

# %%
df.loc[:,'limite_adicional'].value_counts(normalize = True)
# Out:
# limite_adicional
# Negar       0.841579
# Conceder    0.158421
# Name: proportion, dtype: float64

# %% [markdown]
# ## 2.0 Seleção Features

# %%
features = ['idade', 'saldo_atual', 'divida_atual', 'renda_anual',
       'valor_em_investimentos', 'taxa_utilizacao_credito', 'num_emprestimos',
       'num_contas_bancarias', 'num_cartoes_credito', 'dias_atraso_dt_venc',
       'num_pgtos_atrasados', 'num_consultas_credito', 'taxa_juros']

label = 'limite_adicional'

x_train = df.loc[: , features]
y_train = df.loc[:, label].values

# %% [markdown]
# ## 3.0 Treinamento

# %%
#definição de parametros treinamento
k = 3
knn_classifier = KNeighborsClassifier ( n_neighbors = k )
#treinamento algoritmo
knn_classifier.fit(x_train , y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred = knn_classifier.predict(x_train )

# %%
df_result = df.copy()

# %%
df_result.head()
df_result['classificacao'] = y_pred

# %% [markdown]
# ## 4.0 Performance

# %% [markdown]
# ### 4.1 Matriz de confusão

# %%
mt.confusion_matrix(y_train, y_pred)
# Out:
# array([[ 705,  800],
#        [ 288, 7707]])

# %% [markdown]
# ### 4.2 Acurácia

# %%
mt.accuracy_score(y_train, y_pred)
# Out:
# 0.8854736842105263

# %% [markdown]
# ### 4.3 Precisão

# %%
mt.precision_score(y_train, y_pred, pos_label ='Conceder')
# Out:
# 0.7099697885196374

# %% [markdown]
# ### 4.4 Recall

# %%
mt.recall_score( y_train, y_pred, pos_label='Conceder')
# Out:
# 0.4684385382059801

# %%
df_result.loc[: , ['id_cliente' , 'idade', 'limite_adicional', 'classificacao']].sample(10)
# Out:
#       id_cliente  idade limite_adicional classificacao
# 7952       12357     55         Conceder      Conceder
# 3565        2917     58         Conceder         Negar
# 6459         814     19            Negar         Negar
# 8932       10276     35            Negar         Negar
# 8226       10639     49            Negar         Negar
# 384         1324     33            Negar         Negar
# 9432        1969     48            Negar         Negar
# 9338        1475     47            Negar      Conceder
# 8720       12044     19            Negar         Negar
# 2377        9459     47         Conceder         Negar

# %%
df_result.head()
# Out:
#    id_cliente  idade  saldo_atual  divida_atual  renda_anual  \
# 0        1767     21   278.172008       2577.05  24196.89636
# 1       11920     40   268.874152       2465.39  19227.37796
# 2        8910     36   446.643127       1055.29  42822.28223
# 3        4964     58   321.141267        703.05  51786.82600
# 4       10100     35   428.716114        891.29  44626.85346
#
#    valor_em_investimentos  taxa_utilizacao_credito  num_emprestimos  \
# 0              104.306544                31.038763                6
# 1               69.858778                36.917093                5
# 2              134.201478                34.561714                0
# 3              297.350067                31.493561                0
# 4              134.201478                28.028887                2
#
#    num_contas_bancarias  num_cartoes_credito  dias_atraso_dt_venc  \
# 0                     5                    7                   21
# 1                     8                    5                   40
# 2                     3                    6                   26
# 3                     3                    7                   12
# 4                     8                    7                   24
#
#    num_pgtos_atrasados  num_consultas_credito  taxa_juros investe_exterior  \
# 0                   14                      9          15              Não
# 1                   23                     10          18              Não
# 2                   13                      3          15              Sim
# 3                    7                      2           1              Sim
# 4                   10                      8          20              Sim
#
#   pessoa_polit_exp limite_adicional classificacao
# 0              Não            Negar         Negar
# 1              Não            Negar         Negar
# 2              Não            Negar         Negar
# 3              Não            Negar         Negar
# 4              Não            Negar         Negar

# %%
#criando coluna para verificar acurácia manualmente
df_result['acertos'] = (df_result.loc[:,['id_cliente', 'limite_adicional', 'classificacao']].apply( lambda x: 1 if x['limite_adicional'] == x['classificacao'] else 0, axis =1))

# %%
df_result.loc[:,'acertos'].value_counts(normalize = True)
# Out:
# acertos
# 1    0.885474
# 0    0.114526
# Name: proportion, dtype: float64
